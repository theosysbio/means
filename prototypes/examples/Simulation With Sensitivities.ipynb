# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (8.0, 8.0) # make plots a bit larger
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import means
import means.examples
import numpy as np
import matplotlib.pyplot as plt

# %%
model = means.model.Model(['k_1', 'k_2'], ['x_1', 'x_2'], ['k_1*x_1*(x_1-1)', 'k_2*x_2'], [[-2, 2], [1, -1]])

# %%
parameters = [1.66e-3, 0.2]
initial_conditions = [301, 0]
timepoints = np.arange(0, 20, 0.1)

# %%
MOMENT_ORDER = 6

# %%
problem = means.approximation.MomentExpansionApproximation(model, MOMENT_ORDER).run()

# %%
problem
# Out:
# <class 'means.approximation.ode_problem.ODEProblem'>
# Method: 'MEA'
# Constants: [k_1, k_2]
#
# Equations:
#
# Moment(array([1, 0]), symbol=x_1):
#     -2*k_1*x_1**2 + 2*k_1*x_1 - 2*k_1*yx11 + 2*k_2*x_2
#
# Moment(array([0, 1]), symbol=x_2):
#     k_1*x_1*(x_1 - 1) + k_1*yx11 - k_2*x_2
#
# Moment(array([0, 2]), symbol=yx1):
#     k_1*x_1**2 - k_1*x_1 + k_1*yx11 + 2*k_1*yx12 + 2*k_1*yx6*(2*x_1 - 1) + k_2*x_2 - 2*k_2*yx1
#
# Moment(array([0, 3]), symbol=yx2):
#     k_1*x_1**2 + 6*k_1*x_1*yx6 + 6*k_1*x_1*yx7 - k_1*x_1 - 3*k_1*yx1*yx11 + k_1*yx11 + 3*k_1*yx12 + 3*k_1*yx13 - 3*k_1*yx6 - 3*k_1*yx7 - k_2*x_2 + 3*k_2*yx1 - 3*k_2*yx2
#
# Moment(array([0, 4]), symbol=yx3):
#     6*k_1*x_1**2*yx1 + k_1*x_1**2 - 6*k_1*x_1*yx1 + 8*k_1*x_1*yx6 + 12*k_1*x_1*yx7 + 8*k_1*x_1*yx8 - k_1*x_1 - 4*k_1*yx11*yx2 + k_1*yx11 + 4*k_1*yx12 + 6*k_1*yx13 + 4*k_1*yx14 - 4*k_1*yx6 - 6*k_1*yx7 - 4*k_1*yx8 + 6*k_2*x_2*yx1 + k_2*x_2 - 4*k_2*yx1 + 6*k_2*yx2 - 4*k_2*yx3
#
# Moment(array([0, 5]), symbol=yx4):
#     10*k_1*x_1**2*yx1 + 10*k_1*x_1**2*yx2 + k_1*x_1**2 - 10*k_1*x_1*yx1 - 10*k_1*x_1*yx2 + 10*k_1*x_1*yx6 + 20*k_1*x_1*yx7 + 20*k_1*x_1*yx8 + 10*k_1*x_1*yx9 - k_1*x_1 - 5*k_1*yx11*yx3 + k_1*yx11 + 5*k_1*yx12 + 10*k_1*yx13 + 10*k_1*yx14 + 5*k_1*yx15 - 5*k_1*yx6 - 10*k_1*yx7 - 10*k_1*yx8 - 5*k_1*yx9 - 10*k_2*x_2*yx1 + 10*k_2*x_2*yx2 - k_2*x_2 + 5*k_2*yx1 - 10*k_2*yx2 + 10*k_2*yx3 - 5*k_2*yx4
#
# Moment(array([0, 6]), symbol=yx5):
#     15*k_1*x_1**2*yx1 + 20*k_1*x_1**2*yx2 + 15*k_1*x_1**2*yx3 + k_1*x_1**2 - 15*k_1*x_1*yx1 + 12*k_1*x_1*yx10 - 20*k_1*x_1*yx2 - 15*k_1*x_1*yx3 + 12*k_1*x_1*yx6 + 30*k_1*x_1*yx7 + 40*k_1*x_1*yx8 + 30*k_1*x_1*yx9 - k_1*x_1 - 6*k_1*yx10 - 6*k_1*yx11*yx4 + k_1*yx11 + 6*k_1*yx12 + 15*k_1*yx13 + 20*k_1*yx14 + 15*k_1*yx15 - 6*k_1*yx6 - 15*k_1*yx7 - 20*k_1*yx8 - 15*k_1*yx9 + 15*k_2*x_2*yx1 - 20*k_2*x_2*yx2 + 15*k_2*x_2*yx3 + k_2*x_2 - 6*k_2*yx1 + 15*k_2*yx2 - 20*k_2*yx3 + 15*k_2*yx4 - 6*k_2*yx5
#
# Moment(array([1, 1]), symbol=yx6):
#     -2*k_1*x_1**2 + 2*k_1*x_1 + k_1*yx11*(2*x_1 - 3) - 2*k_1*yx12 + k_1*yx16 - 2*k_2*x_2 + 2*k_2*yx1 - yx6*(4*k_1*x_1 - 2*k_1 + k_2)
#
# Moment(array([1, 2]), symbol=yx7):
#     -2*k_1*x_1**2 + 2*k_1*x_1*yx11 + 4*k_1*x_1*yx12 - 8*k_1*x_1*yx6 - 4*k_1*x_1*yx7 + 2*k_1*x_1 + 2*k_1*yx1*yx11 - 2*k_1*yx11*yx6 - 3*k_1*yx11 - 6*k_1*yx12 - 2*k_1*yx13 + k_1*yx16 + 2*k_1*yx17 + 4*k_1*yx6 + 2*k_1*yx7 + 2*k_2*x_2 - 4*k_2*yx1 + 2*k_2*yx2 + k_2*yx6 - 2*k_2*yx7
#
# Moment(array([1, 3]), symbol=yx8):
#     -6*k_1*x_1**2*yx1 + 3*k_1*x_1**2*yx6 - 2*k_1*x_1**2 + 6*k_1*x_1*yx1 + 2*k_1*x_1*yx11 + 6*k_1*x_1*yx12 + 6*k_1*x_1*yx13 - 15*k_1*x_1*yx6 - 12*k_1*x_1*yx7 - 4*k_1*x_1*yx8 + 2*k_1*x_1 + 2*k_1*yx11*yx2 - 3*k_1*yx11*yx7 - 3*k_1*yx11 - 9*k_1*yx12 - 9*k_1*yx13 - 2*k_1*yx14 + k_1*yx16 + 3*k_1*yx17 + 3*k_1*yx18 + 6*k_1*yx6 + 6*k_1*yx7 + 2*k_1*yx8 - 6*k_2*x_2*yx1 + 3*k_2*x_2*yx6 - 2*k_2*x_2 + 6*k_2*yx1 - 6*k_2*yx2 + 2*k_2*yx3 - k_2*yx6 + 3*k_2*yx7 - 3*k_2*yx8
#
# Moment(array([1, 4]), symbol=yx9):
#     -12*k_1*x_1**2*yx1 - 8*k_1*x_1**2*yx2 + 4*k_1*x_1**2*yx6 + 6*k_1*x_1**2*yx7 - 2*k_1*x_1**2 + 12*k_1*x_1*yx1 + 2*k_1*x_1*yx11 + 8*k_1*x_1*yx12 + 12*k_1*x_1*yx13 + 8*k_1*x_1*yx14 + 8*k_1*x_1*yx2 - 20*k_1*x_1*yx6 - 30*k_1*x_1*yx7 - 16*k_1*x_1*yx8 - 4*k_1*x_1*yx9 + 2*k_1*x_1 + 2*k_1*yx11*yx3 - 4*k_1*yx11*yx8 - 3*k_1*yx11 - 12*k_1*yx12 - 18*k_1*yx13 - 12*k_1*yx14 - 2*k_1*yx15 + k_1*yx16 + 4*k_1*yx17 + 6*k_1*yx18 + 4*k_1*yx19 + 8*k_1*yx6 + 12*k_1*yx7 + 8*k_1*yx8 + 2*k_1*yx9 + 12*k_2*x_2*yx1 - 8*k_2*x_2*yx2 - 4*k_2*x_2*yx6 + 6*k_2*x_2*yx7 + 2*k_2*x_2 - 8*k_2*yx1 + 12*k_2*yx2 - 8*k_2*yx3 + 2*k_2*yx4 + k_2*yx6 - 4*k_2*yx7 + 6*k_2*yx8 - 4*k_2*yx9
#
# Moment(array([1, 5]), symbol=yx10):
#     -20*k_1*x_1**2*yx1 - 20*k_1*x_1**2*yx2 - 10*k_1*x_1**2*yx3 + 5*k_1*x_1**2*yx6 + 10*k_1*x_1**2*yx7 + 10*k_1*x_1**2*yx8 - 2*k_1*x_1**2 + 20*k_1*x_1*yx1 - 4*k_1*x_1*yx10 + 2*k_1*x_1*yx11 + 10*k_1*x_1*yx12 + 20*k_1*x_1*yx13 + 20*k_1*x_1*yx14 + 10*k_1*x_1*yx15 + 20*k_1*x_1*yx2 + 10*k_1*x_1*yx3 - 25*k_1*x_1*yx6 - 50*k_1*x_1*yx7 - 50*k_1*x_1*yx8 - 20*k_1*x_1*yx9 + 2*k_1*x_1 + 2*k_1*yx10 + 2*k_1*yx11*yx4 - 5*k_1*yx11*yx9 - 3*k_1*yx11 - 15*k_1*yx12 - 30*k_1*yx13 - 30*k_1*yx14 - 15*k_1*yx15 + k_1*yx16 + 5*k_1*yx17 + 10*k_1*yx18 + 10*k_1*yx19 + 10*k_1*yx6 + 20*k_1*yx7 + 20*k_1*yx8 + 10*k_1*yx9 - 20*k_2*x_2*yx1 + 20*k_2*x_2*yx2 - 10*k_2*x_2*yx3 + 5*k_2*x_2*yx6 - 10*k_2*x_2*yx7 + 10*k_2*x_2*yx8 - 2*k_2*x_2 + 10*k_2*yx1 - 5*k_2*yx10 - 20*k_2*yx2 + 20*k_2*yx3 - 10*k_2*yx4 + 2*k_2*yx5 - k_2*yx6 + 5*k_2*yx7 - 10*k_2*yx8 + 10*k_2*yx9
#
# Moment(array([2, 0]), symbol=yx11):
#     4*k_1*x_1**2 - 8*k_1*x_1*yx11 - 4*k_1*x_1 + 8*k_1*yx11 - 4*k_1*yx16 + 4*k_2*x_2 + 4*k_2*yx6
#
# Moment(array([2, 1]), symbol=yx12):
#     4*k_1*x_1**2 - 8*k_1*x_1*yx11 - 8*k_1*x_1*yx12 + 2*k_1*x_1*yx16 + 8*k_1*x_1*yx6 - 4*k_1*x_1 - k_1*yx11**2 + 4*k_1*yx11*yx6 + 8*k_1*yx11 + 8*k_1*yx12 - 5*k_1*yx16 - 4*k_1*yx17 + k_1*yx20 - 4*k_1*yx6 - 4*k_2*x_2 + 4*k_2*yx1 - k_2*yx12 - 4*k_2*yx6 + 4*k_2*yx7
#
# Moment(array([2, 2]), symbol=yx13):
#     4*k_1*x_1**2*yx1 + k_1*x_1**2*yx11 - 8*k_1*x_1**2*yx6 + 4*k_1*x_1**2 - 4*k_1*x_1*yx1 - 9*k_1*x_1*yx11 - 16*k_1*x_1*yx12 - 8*k_1*x_1*yx13 + 2*k_1*x_1*yx16 + 4*k_1*x_1*yx17 + 24*k_1*x_1*yx6 + 8*k_1*x_1*yx7 - 4*k_1*x_1 - 2*k_1*yx11*yx12 + 4*k_1*yx11*yx7 + 8*k_1*yx11 + 16*k_1*yx12 + 8*k_1*yx13 - 5*k_1*yx16 - 10*k_1*yx17 - 4*k_1*yx18 + k_1*yx20 + 2*k_1*yx21 - 8*k_1*yx6 - 4*k_1*yx7 + 4*k_2*x_2*yx1 + k_2*x_2*yx11 - 8*k_2*x_2*yx6 + 4*k_2*x_2 - 8*k_2*yx1 + k_2*yx12 - 2*k_2*yx13 + 4*k_2*yx2 + 4*k_2*yx6 - 8*k_2*yx7 + 4*k_2*yx8
#
# Moment(array([2, 3]), symbol=yx14):
#     12*k_1*x_1**2*yx1 + k_1*x_1**2*yx11 + 3*k_1*x_1**2*yx12 + 4*k_1*x_1**2*yx2 - 12*k_1*x_1**2*yx6 - 12*k_1*x_1**2*yx7 + 4*k_1*x_1**2 - 12*k_1*x_1*yx1 - 9*k_1*x_1*yx11 - 27*k_1*x_1*yx12 - 24*k_1*x_1*yx13 - 8*k_1*x_1*yx14 + 2*k_1*x_1*yx16 + 6*k_1*x_1*yx17 + 6*k_1*x_1*yx18 - 4*k_1*x_1*yx2 + 36*k_1*x_1*yx6 + 36*k_1*x_1*yx7 + 8*k_1*x_1*yx8 - 4*k_1*x_1 - 3*k_1*yx11*yx13 + 4*k_1*yx11*yx8 + 8*k_1*yx11 + 24*k_1*yx12 + 24*k_1*yx13 + 8*k_1*yx14 - 5*k_1*yx16 - 15*k_1*yx17 - 15*k_1*yx18 - 4*k_1*yx19 + k_1*yx20 + 3*k_1*yx21 + 3*k_1*yx22 - 12*k_1*yx6 - 12*k_1*yx7 - 4*k_1*yx8 - 12*k_2*x_2*yx1 - k_2*x_2*yx11 + 3*k_2*x_2*yx12 + 4*k_2*x_2*yx2 + 12*k_2*x_2*yx6 - 12*k_2*x_2*yx7 - 4*k_2*x_2 + 12*k_2*yx1 - k_2*yx12 + 3*k_2*yx13 - 3*k_2*yx14 - 12*k_2*yx2 + 4*k_2*yx3 - 4*k_2*yx6 + 12*k_2*yx7 - 12*k_2*yx8 + 4*k_2*yx9
#
# Moment(array([2, 4]), symbol=yx15):
#     -4*k_1*x_1**2*yx14 + 4*k_1*x_1**2*yx9 + 4*k_1*x_1**2 + 4*k_1*x_1*yx14 - 4*k_1*x_1*yx9 - 4*k_1*x_1 + k_1*yx16*(2*x_1 - 5) + 4*k_1*yx17*(2*x_1 - 5) + 6*k_1*yx18*(2*x_1 - 5) + 4*k_1*yx19*(2*x_1 - 5) + k_1*yx20 + 4*k_1*yx21 + 6*k_1*yx22 + 4*k_2*x_2*yx14 - 4*k_2*x_2*yx9 + 4*k_2*x_2 + 4*k_2*yx10 + 4*k_2*yx4 + yx1*(24*k_1*x_1**2 - 24*k_1*x_1 + 24*k_2*x_2 - 16*k_2) + yx11*(k_1*x_1**2 - 9*k_1*x_1 - 4*k_1*yx14 + 4*k_1*yx9 + 8*k_1 + k_2*x_2) + yx12*(4*k_1*x_1**2 - 36*k_1*x_1 + 32*k_1 - 4*k_2*x_2 + k_2) + yx13*(6*k_1*x_1**2 - 54*k_1*x_1 + 48*k_1 + 6*k_2*x_2 - 4*k_2) + yx14*(4*k_1*x_1**2 - 36*k_1*x_1 + 32*k_1 - 4*k_2*x_2 + 6*k_2) - yx15*(8*k_1*x_1 - 8*k_1 + 4*k_2) + yx2*(16*k_1*x_1**2 - 16*k_1*x_1 - 16*k_2*x_2 + 24*k_2) + yx3*(4*k_1*x_1**2 - 4*k_1*x_1 + 4*k_2*x_2 - 16*k_2) - yx6*(16*k_1*x_1**2 - 48*k_1*x_1 + 16*k_1 + 16*k_2*x_2 - 4*k_2) - yx7*(24*k_1*x_1**2 - 72*k_1*x_1 + 24*k_1 - 24*k_2*x_2 + 16*k_2) - yx8*(16*k_1*x_1**2 - 48*k_1*x_1 + 16*k_1 + 16*k_2*x_2 - 24*k_2) - yx9*(4*k_1*x_1**2 - 12*k_1*x_1 + 4*k_1 - 4*k_2*x_2 + 16*k_2)
#
# Moment(array([3, 0]), symbol=yx16):
#     -8*k_1*x_1**2 + 24*k_1*x_1*yx11 - 12*k_1*x_1*yx16 + 8*k_1*x_1 + 6*k_1*yx11**2 - 20*k_1*yx11 + 18*k_1*yx16 - 6*k_1*yx20 + 8*k_2*x_2 + 6*k_2*yx12 + 12*k_2*yx6
#
# Moment(array([3, 1]), symbol=yx17):
#     -6*k_1*x_1**2*yx11 + 12*k_1*x_1**2*yx6 - 8*k_1*x_1**2 + 30*k_1*x_1*yx11 + 24*k_1*x_1*yx12 - 12*k_1*x_1*yx16 - 12*k_1*x_1*yx17 + 2*k_1*x_1*yx20 - 28*k_1*x_1*yx6 + 8*k_1*x_1 + 6*k_1*yx11*yx12 - k_1*yx11*yx16 - 20*k_1*yx11 - 20*k_1*yx12 + 18*k_1*yx16 + 18*k_1*yx17 - 7*k_1*yx20 - 6*k_1*yx21 + k_1*yx23 + 8*k_1*yx6 - 6*k_2*x_2*yx11 + 12*k_2*x_2*yx6 - 8*k_2*x_2 + 8*k_2*yx1 - 6*k_2*yx12 + 6*k_2*yx13 - k_2*yx17 - 12*k_2*yx6 + 12*k_2*yx7
#
# Moment(array([3, 2]), symbol=yx18):
#     -8*k_1*x_1**2*yx1 - 6*k_1*x_1**2*yx11 - 12*k_1*x_1**2*yx12 + k_1*x_1**2*yx16 + 24*k_1*x_1**2*yx6 + 12*k_1*x_1**2*yx7 - 8*k_1*x_1**2 + 8*k_1*x_1*yx1 + 30*k_1*x_1*yx11 + 60*k_1*x_1*yx12 + 24*k_1*x_1*yx13 - 13*k_1*x_1*yx16 - 24*k_1*x_1*yx17 - 12*k_1*x_1*yx18 + 2*k_1*x_1*yx20 + 4*k_1*x_1*yx21 - 56*k_1*x_1*yx6 - 28*k_1*x_1*yx7 + 8*k_1*x_1 + 6*k_1*yx11*yx13 - 2*k_1*yx11*yx17 - 20*k_1*yx11 - 40*k_1*yx12 - 20*k_1*yx13 + 18*k_1*yx16 + 36*k_1*yx17 + 18*k_1*yx18 - 7*k_1*yx20 - 14*k_1*yx21 - 6*k_1*yx22 + k_1*yx23 + 2*k_1*yx24 + 16*k_1*yx6 + 8*k_1*yx7 + 8*k_2*x_2*yx1 + 6*k_2*x_2*yx11 - 12*k_2*x_2*yx12 + k_2*x_2*yx16 - 24*k_2*x_2*yx6 + 12*k_2*x_2*yx7 + 8*k_2*x_2 - 16*k_2*yx1 + 6*k_2*yx12 - 12*k_2*yx13 + 6*k_2*yx14 + k_2*yx17 - 2*k_2*yx18 + 8*k_2*yx2 + 12*k_2*yx6 - 24*k_2*yx7 + 12*k_2*yx8
#
# Moment(array([3, 3]), symbol=yx19):
#     6*k_1*x_1**2*yx14 - 3*k_1*x_1**2*yx18 - 8*k_1*x_1**2 - 6*k_1*x_1*yx14 + 3*k_1*x_1*yx18 + 8*k_1*x_1 + k_1*yx20*(2*x_1 - 7) + 3*k_1*yx21*(2*x_1 - 7) + 3*k_1*yx22*(2*x_1 - 7) + k_1*yx23 + 3*k_1*yx24 - 6*k_2*x_2*yx14 + 3*k_2*x_2*yx18 - 8*k_2*x_2 + 6*k_2*yx15 + 8*k_2*yx3 + 12*k_2*yx9 - 24*yx1*(k_1*x_1**2 - k_1*x_1 + k_2*x_2 - k_2) - yx11*(6*k_1*x_1**2 - 30*k_1*x_1 - 6*k_1*yx14 + 3*k_1*yx18 + 20*k_1 + 6*k_2*x_2) - 6*yx12*(3*k_1*x_1**2 - 15*k_1*x_1 + 10*k_1 - 3*k_2*x_2 + k_2) - 6*yx13*(3*k_1*x_1**2 - 15*k_1*x_1 + 10*k_1 + 3*k_2*x_2 - 3*k_2) - 2*yx14*(3*k_1*x_1**2 - 15*k_1*x_1 + 10*k_1 - 3*k_2*x_2 + 9*k_2) + yx16*(k_1*x_1**2 - 13*k_1*x_1 + 18*k_1 - k_2*x_2) + yx17*(3*k_1*x_1**2 - 39*k_1*x_1 + 54*k_1 + 3*k_2*x_2 - k_2) + 3*yx18*(k_1*x_1**2 - 13*k_1*x_1 + 18*k_1 - k_2*x_2 + k_2) - 3*yx19*(4*k_1*x_1 - 6*k_1 + k_2) - 8*yx2*(k_1*x_1**2 - k_1*x_1 - k_2*x_2 + 3*k_2) + 12*yx6*(3*k_1*x_1**2 - 7*k_1*x_1 + 2*k_1 + 3*k_2*x_2 - k_2) + 12*yx7*(3*k_1*x_1**2 - 7*k_1*x_1 + 2*k_1 - 3*k_2*x_2 + 3*k_2) + 4*yx8*(3*k_1*x_1**2 - 7*k_1*x_1 + 2*k_1 + 3*k_2*x_2 - 9*k_2)
#
# Moment(array([4, 0]), symbol=yx20):
#     24*k_1*x_1**2*yx11 + 16*k_1*x_1**2 - 88*k_1*x_1*yx11 + 48*k_1*x_1*yx16 - 16*k_1*x_1*yx20 - 16*k_1*x_1 + 8*k_1*yx11*yx16 + 48*k_1*yx11 - 56*k_1*yx16 + 32*k_1*yx20 - 8*k_1*yx23 + 24*k_2*x_2*yx11 + 16*k_2*x_2 + 24*k_2*yx12 + 8*k_2*yx17 + 32*k_2*yx6
#
# Moment(array([4, 1]), symbol=yx21):
#     24*k_1*x_1**2*yx11 + 24*k_1*x_1**2*yx12 - 8*k_1*x_1**2*yx16 - 32*k_1*x_1**2*yx6 + 16*k_1*x_1**2 - 88*k_1*x_1*yx11 - 88*k_1*x_1*yx12 + 56*k_1*x_1*yx16 + 48*k_1*x_1*yx17 - 16*k_1*x_1*yx20 - 16*k_1*x_1*yx21 + 2*k_1*x_1*yx23 + 64*k_1*x_1*yx6 - 16*k_1*x_1 + 8*k_1*yx11*yx17 - k_1*yx11*yx20 + 48*k_1*yx11 + 48*k_1*yx12 - 56*k_1*yx16 - 56*k_1*yx17 + 32*k_1*yx20 + 32*k_1*yx21 - 9*k_1*yx23 - 8*k_1*yx24 + k_1*yx25 - 16*k_1*yx6 - 24*k_2*x_2*yx11 + 24*k_2*x_2*yx12 - 8*k_2*x_2*yx16 + 32*k_2*x_2*yx6 - 16*k_2*x_2 + 16*k_2*yx1 - 24*k_2*yx12 + 24*k_2*yx13 - 8*k_2*yx17 + 8*k_2*yx18 - k_2*yx21 - 32*k_2*yx6 + 32*k_2*yx7
#
# Moment(array([4, 2]), symbol=yx22):
#     8*k_1*x_1**2*yx18 - 2*k_1*x_1**2*yx21 + 16*k_1*x_1**2 - 8*k_1*x_1*yx18 + 2*k_1*x_1*yx21 - 16*k_1*x_1 + k_1*yx23*(2*x_1 - 9) + 2*k_1*yx24*(2*x_1 - 9) + k_1*yx25 - 8*k_2*x_2*yx18 + 2*k_2*x_2*yx21 + 16*k_2*x_2 + 24*k_2*yx14 + 8*k_2*yx19 + 16*k_2*yx2 + 32*k_2*yx8 + 16*yx1*(k_1*x_1**2 - k_1*x_1 + k_2*x_2 - 2*k_2) + 2*yx11*(12*k_1*x_1**2 - 44*k_1*x_1 + 4*k_1*yx18 - k_1*yx21 + 24*k_1 + 12*k_2*x_2) + 8*yx12*(6*k_1*x_1**2 - 22*k_1*x_1 + 12*k_1 - 6*k_2*x_2 + 3*k_2) + 8*yx13*(3*k_1*x_1**2 - 11*k_1*x_1 + 6*k_1 + 3*k_2*x_2 - 6*k_2) - 8*yx16*(k_1*x_1**2 - 7*k_1*x_1 + 7*k_1 - k_2*x_2) - 8*yx17*(2*k_1*x_1**2 - 14*k_1*x_1 + 14*k_1 + 2*k_2*x_2 - k_2) - 8*yx18*(k_1*x_1**2 - 7*k_1*x_1 + 7*k_1 - k_2*x_2 + 2*k_2) + yx20*(k_1*x_1**2 - 17*k_1*x_1 + 32*k_1 + k_2*x_2) + yx21*(2*k_1*x_1**2 - 34*k_1*x_1 + 64*k_1 - 2*k_2*x_2 + k_2) - 2*yx22*(8*k_1*x_1 - 16*k_1 + k_2) - 32*yx6*(2*k_1*x_1**2 - 4*k_1*x_1 + k_1 + 2*k_2*x_2 - k_2) - 16*yx7*(2*k_1*x_1**2 - 4*k_1*x_1 + k_1 - 2*k_2*x_2 + 4*k_2)
#
# Moment(array([5, 0]), symbol=yx23):
#     -80*k_1*x_1**2*yx11 + 40*k_1*x_1**2*yx16 - 32*k_1*x_1**2 + 240*k_1*x_1*yx11 - 200*k_1*x_1*yx16 + 80*k_1*x_1*yx20 - 20*k_1*x_1*yx23 + 32*k_1*x_1 + 10*k_1*yx11*yx20 - 112*k_1*yx11 + 160*k_1*yx16 - 120*k_1*yx20 + 50*k_1*yx23 - 10*k_1*yx25 + 80*k_2*x_2*yx11 + 40*k_2*x_2*yx16 + 32*k_2*x_2 + 80*k_2*yx12 + 40*k_2*yx17 + 10*k_2*yx21 + 80*k_2*yx6
#
# Moment(array([5, 1]), symbol=yx24):
#     -80*k_1*x_1**2*yx11 - 80*k_1*x_1**2*yx12 + 40*k_1*x_1**2*yx16 + 40*k_1*x_1**2*yx17 - 10*k_1*x_1**2*yx20 + 80*k_1*x_1**2*yx6 - 32*k_1*x_1**2 + 240*k_1*x_1*yx11 + 240*k_1*x_1*yx12 - 200*k_1*x_1*yx16 - 200*k_1*x_1*yx17 + 90*k_1*x_1*yx20 + 80*k_1*x_1*yx21 - 20*k_1*x_1*yx23 - 20*k_1*x_1*yx24 + 2*k_1*x_1*yx25 - 144*k_1*x_1*yx6 + 32*k_1*x_1 + 10*k_1*yx11*yx21 - k_1*yx11*yx23 - 112*k_1*yx11 - 112*k_1*yx12 + 160*k_1*yx16 + 160*k_1*yx17 - 120*k_1*yx20 - 120*k_1*yx21 + 50*k_1*yx23 + 50*k_1*yx24 - 11*k_1*yx25 + 32*k_1*yx6 - 80*k_2*x_2*yx11 + 80*k_2*x_2*yx12 - 40*k_2*x_2*yx16 + 40*k_2*x_2*yx17 - 10*k_2*x_2*yx20 + 80*k_2*x_2*yx6 - 32*k_2*x_2 + 32*k_2*yx1 - 80*k_2*yx12 + 80*k_2*yx13 - 40*k_2*yx17 + 40*k_2*yx18 - 10*k_2*yx21 + 10*k_2*yx22 - k_2*yx24 - 80*k_2*yx6 + 80*k_2*yx7
#
# Moment(array([6, 0]), symbol=yx25):
#     240*k_1*x_1**2*yx11 - 160*k_1*x_1**2*yx16 + 60*k_1*x_1**2*yx20 + 64*k_1*x_1**2 - 624*k_1*x_1*yx11 + 640*k_1*x_1*yx16 - 380*k_1*x_1*yx20 + 120*k_1*x_1*yx23 - 24*k_1*x_1*yx25 - 64*k_1*x_1 + 12*k_1*yx11*yx23 + 256*k_1*yx11 - 432*k_1*yx16 + 400*k_1*yx20 - 220*k_1*yx23 + 72*k_1*yx25 + 240*k_2*x_2*yx11 + 160*k_2*x_2*yx16 + 60*k_2*x_2*yx20 + 64*k_2*x_2 + 240*k_2*yx12 + 160*k_2*yx17 + 60*k_2*yx21 + 12*k_2*yx24 + 192*k_2*yx6

# %%
simulation = means.simulation.SimulationWithSensitivities(problem)

# %%
trajectories = simulation.simulate_system(parameters, initial_conditions, timepoints)

# %%
for trajectory in trajectories:
    if trajectory.description.order != 1:
        continue
        
    plt.subplot(3,1,1)
    trajectory.plot()
    plt.title('Means')
    plt.legend(loc='lower left', bbox_to_anchor = (1, 0))
    
    for i, sensitivity_trajectory in enumerate(trajectory.sensitivity_data):
        plt.subplot(3,1,2+i)
        plt.title('Sensitivities {0}'.format(sensitivity_trajectory.description.parameter))
        sensitivity_trajectory.plot()
        plt.legend(loc='lower left', bbox_to_anchor = (1, 0))

# %%
plt.close()
