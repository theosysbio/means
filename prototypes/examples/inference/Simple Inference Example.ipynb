# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import means
import means.examples

# %%
import numpy as np

# %% [markdown]
# We will start with a simple parameter inference example, for the parameter dimerisation model:

# %%
model = means.examples.sample_models.MODEL_DIMERISATION

# %%
model
# Out:
# <class 'means.model.model.Model'>
# Species: [y_0]
# Constants: [c_0, c_1, c_2]
#
# Stoichiometry matrix:
# Matrix([[-2, 2]])
#
# Propensities:
# Matrix([
# [      c_0*y_0*(y_0 - 1)],
# [c_1*(0.5*c_2 - 0.5*y_0)]])

# %% [markdown]
# We first need to have some observed data to be able to perform parameter inference.
#
# We define this data below manually

# %%
timepoints = np.arange(0, 20, 0.5)

# %%
observed_values = np.array([301, 290.191955202941, 280.587012789919, 272.03059275347, 264.391791838931, 
                            257.559062245777, 251.436806654562, 245.94267026554, 241.005368499757, 
                            236.562930313664, 232.561266868355, 228.95299702774, 225.696477184875, 
                            222.754994848608, 220.096094392425, 217.69101016698, 215.514187376472, 
                            213.542875122678, 211.756779127717, 210.13776407335, 208.669597403576, 
                            207.337727947036, 206.129093917824, 205.03195581465, 204.035750512438, 
                            203.130963465903, 202.309016453409, 201.56216870432, 200.883429593812, 
                            200.266481369356, 199.705610605558, 199.19564727630, 198.731910494358, 
                            198.310160102979, 197.926553417265, 197.57760650846, 197.260159505222, 
                            196.971345454330, 196.708562342305, 196.469447928853])

# %% [markdown]
# The data needs to be a list of ``Trajectory`` objects with the specific description field describing which equation the data is for.
#
# Here we define that our data is for the first moment, corresponding to the y_0 symbol.

# %%
# TODO: Expose moment to means.approximation or other package
# TODO: add species= interface for observed data trajectories that would create required raw moment
description = means.approximation.ode_problem.Moment([1], symbol='y_0')
observed_trajectory = means.simulation.Trajectory(timepoints, 
                                                  observed_values, 
                                                  description)

# %%
observed_trajectory.plot('+')

# %% [markdown]
# Make sure to have a list of observed trajectories, even when we have only one

# %%
observed_trajectories = [observed_trajectory]

# %% [markdown]
# Once we have our set of observed trajectories, we need to define the problem we will use to simulate
# the data. Let's use Moment Expansion Approximation with maximum order set to 2.

# %%
problem = means.approximation.MomentExpansionApproximation(model, 2).run()
problem
# Out:
# <class 'means.approximation.ode_problem.ODEProblem'>
# Method: 'MEA'
# Constants: [c_0, c_1, c_2]
#
# Equations:
#
# Moment(array([1]), symbol=y_0):
#     -2*c_0*y_0*(y_0 - 1) - 2*c_0*yx1 + 2*c_1*(0.5*c_2 - 0.5*y_0)
#
# Moment(array([2]), symbol=yx1):
#     -4*c_0*y_0**2*(y_0 - 1) + 4*c_0*y_0*(y_0 - 1) + 4*c_1*y_0*(0.5*c_2 - 0.5*y_0) + 4*c_1*(0.5*c_2 - 0.5*y_0) - 2*y_0*(-2*c_0*y_0*(y_0 - 1) + 2*c_1*(0.5*c_2 - 0.5*y_0)) + yx1*(-4*c_0*y_0 - 4*c_0*(y_0 - 1) + 4*c_0 - 2.0*c_1)

# %% [markdown]
# We now need to define which parameters to make variable, and which ones we should leave constant.
# This is done by specifying a dictionary whose keys are the parameter/initial condition names,
# and the values are the allowed ranges for these parameters.
#
# If a parameter is not listed in this dictionary, it is assumed to be constant.
# If a range is set to None, the variable is assumed to be unbounded

# %%
variable_parameters = {'c_0': (0, 0.001),
                       'c_1': (0, 0.5),
                       # No c_2 - c_2 assumed constatn
                       'y_0': None} # no range for y_0 - y_0 is unbounded

# %% [markdown]
# We can now perform parameter inference from some starting set of parameters.

# %%
inference = means.inference.Inference(problem, 
                                      [0.0001, 0.0001, 0.01], 
                                      [300], 
                                      variable_parameters, 
                                      observed_trajectories)

# %% [markdown]
# To perform the inference, we need to call it's ``infer()`` method:

# %%
result = inference.infer()
result
# Out:
#         <class 'means.inference.results.InferenceResult'>
#         Starting Parameters: [0.0001, 0.0001, 0.01]
#         Optimal Parameters: [4.816507448977715e-05, 0.00013173192442082754, 0.01]
#
#         Starting Initial Conditions: [300, 0.0]
#         Optimal Initial Conditions: [274.30951522652208, 0.0]
#
#         Distance at Minimum: 3891.8386833621548
#         Convergence status: <Inference convergence achieved in 93 iterations and 211 function calls>

# %% [markdown]
# Let's plot the result

# %%
result.plot()

# %% [markdown]
# Now in order to perform parameter inference we need to start somewhere.
#
# Given that the optimisation algorithms often get stuck in local minima,
# and indeed, in this case we seem to have gotten stuck in one.
#
# Due to this, it is often a good idea to perform multiple optimisations from different starting points.
#
# MEANS package implements this method in ``InferenceWithRestarts`` class.

# %% [markdown]
# First let's define the range to sample parameters and initial conditions from:

# %%
parameters_range = [(0, 0.001), (0, 0.5), (260, 330)]
initial_conditions_range = [(290, 320)]

# %% [markdown]
# MEANS ``InferenceWithRestarts`` uses [Latin Hypercube sampling](https://mathieu.fenniak.net/latin-hypercube-sampling/) method to find the initial parameters for simulation.

# %% [markdown]
# Let's seed our random number generator so we can reproduce the same results over and over again (not strictly necessary)

# %%
import random
random.seed(42)
import numpy.random
numpy.random.seed(42)

# %% [markdown]
# We now create an ``InferenceWithRestarts`` instance we will use to perform a multiple parameter inference

# %%
NUMBER_OF_RESTARTS = 10
inference_with_restarts = means.inference.InferenceWithRestarts(problem, 
                                                                NUMBER_OF_RESTARTS, 
                                                                parameters_range,
                                                                initial_conditions_range,
                                                                variable_parameters, 
                                                                observed_trajectories)

# %% [markdown]
# Note that it takes similar parameters to regular inference class,
# with the exception of additional number of restarts parameter, that specifies the number of restarts we expect to have;
# and the initial parameters and initial conditions are now ranges

# %% [markdown]
# We can now perform parameter inference using a similar ``infer()`` method. Note that you can change the ``number_of_processes`` parameter to perform several inferences in parallel

# %%
# %time multiple_inference_result = inference_with_restarts.infer(number_of_processes=1)
multiple_inference_result
# Out:
# CPU times: user 6.83 s, sys: 53.1 ms, total: 6.88 s
# Wall time: 6.88 s
#         <class 'means.inference.results.InferenceResultsCollection'>
#
#         Number of inference results in collection: 10
#         Best:
#
#         <class 'means.inference.results.InferenceResult'>
#         Starting Parameters: [0.0001025010755222667, 0.4801863015683446, 302.70701000586814]
#         Optimal Parameters: [0.00012787658840929304, 0.088397563220421221, 302.70701000586814]
#
#         Starting Initial Conditions: [317.8032226279271, 0.0]
#         Optimal Initial Conditions: [301.00574086536471, 0.0]
#
#         Distance at Minimum: 9.6895797893542632e-05
#         Convergence status: <Inference convergence achieved in 119 iterations and 228 function calls>

# %% [markdown]
# Once the inference is finished, we can plot it's result

# %%
multiple_inference_result.plot()

# %% [markdown]
# Transparent lines show all but the best starting and optimised trajectories, while the solid lines show the best result.
# This best result could be retrieved via `best` property

# %%
print multiple_inference_result.best
multiple_inference_result.best.plot()
# Out:
#         <class 'means.inference.results.InferenceResult'>
#         Starting Parameters: [0.0001025010755222667, 0.4801863015683446, 302.70701000586814]
#         Optimal Parameters: [0.00012787658840929304, 0.088397563220421221, 302.70701000586814]
#
#         Starting Initial Conditions: [317.8032226279271, 0.0]
#         Optimal Initial Conditions: [301.00574086536471, 0.0]
#
#         Distance at Minimum: 9.6895797893542632e-05
#         Convergence status: <Inference convergence achieved in 119 iterations and 228 function calls>
