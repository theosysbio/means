# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
from means.approximation.mea.moment_expansion_approximation import run_mea
import means
from means.examples.sample_models import *

# %%
import numpy as np
import sympy
import pickle

# %%
model = MODEL_P53
constant_values = [90, 0.002, 1.7, 1.1, 0.93, 0.96, 0.01] 
initial_conditions = [70, 30, 60]
timepoints = np.arange(0, 40, .1)

# %%
closer_args = [
               {"closer":"zero"},
               {"closer":"log-normal", "multivariate":True},
               {"closer":"log-normal", "multivariate":False},
               {"closer":"normal", "multivariate":True},
               {"closer":"normal", "multivariate":False}
               ]

# %%
    
all_results = []
try:
    for max_order in range(2,9):
        for cl_arg in closer_args:
            print "simulating for max_order = {0} and closer = {1}".format(max_order, cl_arg)
            probl = run_mea(MODEL_P53, max_order, **cl_arg)
            simulator = means.simulation.Simulation(probl, solver='cvode', discr="BDF",maxord=5, maxh=0.01)
            try:
                trajects = simulator.simulate_system(constant_values, initial_conditions, timepoints)
            except Exception as e:
                print "FAILED WITH {0!r}".format(e)
                trajects = None
                pass
    
            
            if trajects:
                result = dict(cl_arg)
                result["max_order"] = max_order
                result["trajectories"] = trajects
                
                all_results.append(result)
                if  cl_arg.has_key("multivariate") and cl_arg["multivariate"]:
                    multi_or_uni_variate =  "multivariate"
                else:
                    multi_or_uni_variate = 'univariate'
                result["multi_or_uni_variate"] = multi_or_uni_variate
                file_name = "traject_{0}_{1}_{2}.pickle".format(max_order, cl_arg["closer"], multi_or_uni_variate)
                #here I will save result under `file_name`
                
                with open(file_name, 'w') as f:
                    pickle.dump(result, f)
finally:
    with open("traject_everything.pickle", 'w') as f:
        pickle.dump(all_results, f)
# Out:
# simulating for max_order = 2 and closer = {'closer': 'zero'}
# simulating for max_order = 2 and closer = {'closer': 'log-normal', 'multivariate': True}
# [CVode Warning]
#  Internal t = 17.3575 and h = 9.29253e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3575 and h = 9.29253e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3575 and h = 4.80232e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3575 and h = 4.80232e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3575 and h = 2.29231e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3575 and h = 2.29231e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3575 and h = 1.1779e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3575 and h = 1.1779e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3575 and h = 5.25805e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3575 and h = 5.25805e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] The above warning has been issued mxhnil times and will not be issued again for this problem.
# FAILED WITH CVodeError()
# simulating for max_order = 2 and closer = {'closer': 'log-normal', 'multivariate': False}
# [CVode Warning]
#  Internal t = 17.359 and h = 1.22551e-15 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.359 and h = 1.22551e-15 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.359 and h = 6.32042e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.359 and h = 6.32042e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.359 and h = 3.04745e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.359 and h = 3.04745e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.359 and h = 1.56189e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.359 and h = 1.56189e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.359 and h = 7.09233e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.359 and h = 7.09233e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] The above warning has been issued mxhnil times and will not be issued again for this problem.
# FAILED WITH CVodeError()
# simulating for max_order = 2 and closer = {'closer': 'normal', 'multivariate': True}
# simulating for max_order = 2 and closer = {'closer': 'normal', 'multivariate': False}
# simulating for max_order = 3 and closer = {'closer': 'zero'}
# simulating for max_order = 3 and closer = {'closer': 'log-normal', 'multivariate': True}
# simulating for max_order = 3 and closer = {'closer': 'log-normal', 'multivariate': False}
# simulating for max_order = 3 and closer = {'closer': 'normal', 'multivariate': True}
# simulating for max_order = 3 and closer = {'closer': 'normal', 'multivariate': False}
# simulating for max_order = 4 and closer = {'closer': 'zero'}
# simulating for max_order = 4 and closer = {'closer': 'log-normal', 'multivariate': True}
# [CVode Warning]
#  Internal t = 3.923 and h = 2.06928e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.923 and h = 2.06928e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.923 and h = 9.93088e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.923 and h = 9.93088e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.923 and h = 4.85628e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.923 and h = 4.85628e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.923 and h = 2.41151e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.923 and h = 2.41151e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning]
#  Internal t = 3.923 and h = 1.20713e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.923 and h = 1.20713e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] The above warning has been issued mxhnil times and will not be issued again for this problem.
# FAILED WITH CVodeError()
# simulating for max_order = 4 and closer = {'closer': 'log-normal', 'multivariate': False}
# [CVode Warning]
#  Internal t = 3.92244 and h = 1.3382e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.92244 and h = 1.3382e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.92244 and h = 1.3382e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.92244 and h = 1.3382e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.92244 and h = 7.71937e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.92244 and h = 7.71937e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.92244 and h = 1.92984e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.92244 and h = 1.92984e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.92244 and h = 1.92984e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 3.92244 and h = 1.92984e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] The above warning has been issued mxhnil times and will not be issued again for this problem.
# FAILED WITH CVodeError()
# simulating for max_order = 4 and closer = {'closer': 'normal', 'multivariate': True}
# simulating for max_order = 4 and closer = {'closer': 'normal', 'multivariate': False}

# %%
all_results = []
for max_order in range(2,9):
    for cl_arg in closer_args:

        if  cl_arg.has_key("multivariate") and cl_arg["multivariate"]:
            multi_or_uni_variate =  "multivariate"
        else:
            multi_or_uni_variate = 'univariate'

        file_name = "traject_{0}_{1}_{2}.pickle".format(max_order, cl_arg["closer"], multi_or_uni_variate)

        
        try:
            with open(file_name, 'r') as f:
                all_results.append(pickle.load(f))
        except Exception as e:
            print e
            pass

#with open("traject_everything2.pickle", 'w') as f:
#        pickle.dump(all_results, f)
# Out:
# [Errno 2] No such file or directory: 'traject_2_log-normal_multivariate.pickle'
# [Errno 2] No such file or directory: 'traject_2_log-normal_univariate.pickle'
# [Errno 2] No such file or directory: 'traject_4_log-normal_multivariate.pickle'
# [Errno 2] No such file or directory: 'traject_4_log-normal_univariate.pickle'
# [Errno 2] No such file or directory: 'traject_6_log-normal_multivariate.pickle'
# [Errno 2] No such file or directory: 'traject_6_log-normal_univariate.pickle'
# [Errno 2] No such file or directory: 'traject_7_zero_univariate.pickle'
# [Errno 2] No such file or directory: 'traject_7_normal_univariate.pickle'
# [Errno 2] No such file or directory: 'traject_8_zero_univariate.pickle'
# [Errno 2] No such file or directory: 'traject_8_log-normal_multivariate.pickle'
# [Errno 2] No such file or directory: 'traject_8_log-normal_univariate.pickle'
# [Errno 2] No such file or directory: 'traject_8_normal_multivariate.pickle'
# [Errno 2] No such file or directory: 'traject_8_normal_univariate.pickle'

# %%
from matplotlib import pyplot as plt
for i in range(2,8):    
    for n in range(3):
        plt.figure()
        for ar in all_results:
            if ar["trajectories"] and ar["max_order"] == i:
                ar["trajectories"][n].plot(label = "{0}_{1}_{2}".format(ar["max_order"], ar["closer"], ar["multi_or_uni_variate"]))
    
                plt.legend(loc='lower left', bbox_to_anchor = (1, 0))
            
            plt.title("Moment : {0}".format(ar["trajectories"][n].description))
        plt.show()
        plt.close()
