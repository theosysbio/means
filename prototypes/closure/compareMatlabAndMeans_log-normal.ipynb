# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['product']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
import means
#from means.examples.sample_models import *
from means.approximation.ode_problem import parse_problem, ODEProblem
from means.util.sympyhelpers import *

# %%
import numpy as np

# %%
import sympy

# %%
#model = MODEL_P53

# %%
# Values used in Ale et al.
constant_values = [90, 0.002, 1.7, 1.1, 0.93, 0.96, 0.01] 
initial_conditions = [70, 30, 60]
timepoints = np.arange(0, 40, 0.1)

# %% [markdown]
# We can see that matlab and sympy expressions are, empiricaly, the same:

# %%
problem_matlab = parse_problem("matlab_lognorm_n_mom_2.txt")
problem_sympy = parse_problem("sympy_lognorm_n_mom_2.txt")
for m,s in zip(problem_matlab.right_hand_side, problem_sympy.right_hand_side):
    print sympy_empirical_equal(m,s)
    
print problem_matlab.left_hand_side == problem_sympy.left_hand_side
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
simulator_sympy = means.simulation.Simulation(problem_sympy)
trajectories_sympy = simulator_sympy.simulate_system(constant_values, initial_conditions, timepoints)
# Out:
# [CVode Warning] Internal t = 17.3566 and h = 5.35656e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 5.35656e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.62e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 3.74771e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 3.74771e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.36929e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.36929e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 1.50317e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.89957e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 6.70821e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] The above warning has been issued mxhnil times and will not be issued again for this problem.

# %%
simulator_matlab = means.simulation.Simulation(problem_matlab)
trajectories_matlab = simulator_matlab.simulate_system(constant_values, initial_conditions, timepoints)
# Out:
# [CVode Warning] Internal t = 17.3566 and h = 5.21496e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 5.21496e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.3671e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 3.63764e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 3.63764e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.09409e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.09409e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 1.44439e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.75506e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 6.61211e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] The above warning has been issued mxhnil times and will not be issued again for this problem.

# %%
from matplotlib import pyplot as plt

# %%
for tm, sm in zip(trajectories_matlab, trajectories_sympy):
    plt.figure()
    tm.plot(label="matlab expr")
    sm.plot(label="sympy expr")
    #trajectories[1].plot(label=trajectories[1].description.symbol)
    plt.title("Moment compared: {0}".format(tm.description.symbol))
    plt.legend(loc='lower left', bbox_to_anchor = (1, 0))
    plt.show()

# %%
plt.close()

# %% [markdown]
# The huge difference is unexpected: let us try to compare equations in an exact way:

# %%
for m,s in zip(problem_matlab.right_hand_side, problem_sympy.right_hand_side):
    print sympy_expressions_equal(m,s)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# still the same! Let us try to simplify expr

# %%
new_rhs = problem_sympy.right_hand_side.applyfunc(lambda x: sympy.simplify(sympy.expand(x)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-6ae6b9c733b4> in <module>()
#       1 new_rhs = problem_sympy.right_hand_side.applyfunc(lambda x: sympy.simplify(sympy.expand(x)))
#       2 # make a new problem with simplkified exprs:
# ----> 3 problem_sympy_simple = ODEProblem("MEA", problem_sympy.left_hand_side , new_rhs,  problem_sympy.constants)
#
# /home/quentin/comput/MScProj1-git/src/means/approximation/ode_problem.pyc in __init__(self, method, ode_lhs_terms, right_hand_side, constants)
#     160
#     161         self.__ode_lhs_terms = ode_lhs_terms
# --> 162         self.__left_hand_side = to_sympy_column_matrix(sympy.Matrix([plhs.symbol for plhs in ode_lhs_terms]))
#     163         self.__right_hand_side = to_sympy_column_matrix(right_hand_side)
#     164         self.__constants = to_list_of_symbols(constants)
#
# AttributeError: 'Symbol' object has no attribute 'symbol'

# %%
# make a new problem with simplkified exprs:
problem_sympy_simple = ODEProblem("MEA", problem_sympy.ode_lhs_terms , new_rhs,  problem_sympy.constants)

# %%
simulator_sympy_simple = means.simulation.Simulation(problem_sympy_simple)
trajectories_sympy_simple = simulator_sympy_simple.simulate_system(constant_values, initial_conditions, timepoints)
# Out:
# [CVode Warning] Internal t = 17.3566 and h = 5.35659e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 5.35659e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.62004e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 3.74773e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 3.74773e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.36933e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.36933e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 1.50318e-16 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 9.8996e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] Internal t = 17.3566 and h = 6.70824e-17 are such that t + h = t on the next step. The solver will continue anyway.
# [CVode Warning] The above warning has been issued mxhnil times and will not be issued again for this problem.

# %%
for tm,sm, sms in zip(trajectories_matlab, trajectories_sympy, trajectories_sympy_simple):
    plt.figure()
    tm.plot(label="matlab expr")
    sm.plot(label="sympy expr")
    sms.plot(label="sympy simple expr")
    plt.title("Moment compared: {0}".format(tm.description.symbol))
    plt.legend(loc='lower left', bbox_to_anchor = (1, 0))
    plt.show()
