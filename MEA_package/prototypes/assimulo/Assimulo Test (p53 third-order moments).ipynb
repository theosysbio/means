# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
import sympy

# %%
# Parameters for our simulation
start_time = 0.0
timestep = 0.5
end_time = 20.0

# %%
constants = sympy.symbols(['c_0', 'c_1', 'c_2', 'c_3', 'c_4', 'c_5', 'c_6'])
variables = sympy.symbols(['y_0', 'y_1', 'y_2'] + ['yx{0}'.format(x) for x in range(1, 17)])

# %%
# Don't bother trying reading this 
rhs_equations = sympy.Matrix([
                              '-(c_2*c_6*y_2*yx16*(c_6 + y_0)**6 + c_2*c_6*yx4*(c_6 + y_0)**8 + c_2*y_0*y_2*(c_6 + y_0)**9 - (c_0 - c_1*y_0)*(c_6 + y_0)**10 - (c_6 + y_0)**7*(c_2*c_6*y_2*yx6 + c_2*c_6*yx14))/(c_6 + y_0)**10',
'c_3*y_0 - c_4*y_1',
'c_4*y_1 - c_5*y_2',
'c_4*y_1 + 2*c_4*yx2 + c_5*y_2 - 2*c_5*yx1',
'c_3*yx4 - c_4*y_1 + c_4*yx3 - yx2*(c_4 + c_5)',
'c_3*y_0 + 2*c_3*yx5 + c_4*y_1 - 2*c_4*yx3',
'c_2*c_6*y_2*yx14/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) - c_2*y_0*yx1/(c_6 + y_0) + c_2*yx11*(y_0/(c_6 + y_0) - 1)/(c_6 + y_0) + c_4*yx5 - yx4*(2*c_2*y_2*(c_6 + y_0) - c_2*y_2*(c_6 + 2*y_0) + (c_1 + c_5)*(c_6 + y_0)**2)/(c_6 + y_0)**2',
'c_2*c_6*y_2*yx15/(c_6 + y_0)**3 - c_2*y_0*yx2/(c_6 + y_0) + c_2*yx12*(y_0/(c_6 + y_0) - 1)/(c_6 + y_0) + c_3*yx6 - yx5*(c_1 - c_2*y_0*y_2/(c_6 + y_0)**2 + c_2*y_2/(c_6 + y_0) + c_4)',
'c_2*c_6*y_2*yx16*(2*c_6 + 2*y_0 + 1)/(c_6**4 + 4*c_6**3*y_0 + 6*c_6**2*y_0**2 + 4*c_6*y_0**3 + y_0**4) - c_2*c_6*yx14*(-2*c_6 - 2*y_0 - 1)/(-c_6**3 - 3*c_6**2*y_0 - 3*c_6*y_0**2 - y_0**3) + c_2*yx4*(-2*c_6*y_0 + c_6 - 2*y_0**2)/(c_6**2 + 2*c_6*y_0 + y_0**2) + yx6*(2*c_1*c_6**3 + 6*c_1*c_6**2*y_0 + 6*c_1*c_6*y_0**2 + 2*c_1*y_0**3 + 2*c_2*c_6**2*y_2 + 2*c_2*c_6*y_0*y_2 + c_2*c_6*y_2)/(-c_6**3 - 3*c_6**2*y_0 - 3*c_6*y_0**2 - y_0**3) + (c_0*c_6 + c_0*y_0 + c_1*c_6*y_0 + c_1*y_0**2 + c_2*y_0*y_2)/(c_6 + y_0)',
'c_4*y_1 + 3*c_4*yx2 + 3*c_4*yx8 - c_5*y_2 + 3*c_5*yx1 - 3*c_5*yx7',
'c_3*yx11 - c_4*y_1 - 2*c_4*yx2 + c_4*yx3 - c_4*yx8 + 2*c_4*yx9 + c_5*yx2 - 2*c_5*yx8',
'2*c_3*yx12 + c_3*yx4 + c_4*y_1 + c_4*yx10 + c_4*yx2 - 2*c_4*yx3 - 2*c_4*yx9 - c_5*yx9',
'c_3*y_0 + 3*c_3*yx13 + 3*c_3*yx5 - c_4*y_1 - 3*c_4*yx10 + 3*c_4*yx3',
'c_2*c_6*y_2*yx1*yx16/(c_6**4 + 4*c_6**3*y_0 + 6*c_6**2*y_0**2 + 4*c_6*y_0**3 + y_0**4) - c_2*c_6*y_2*yx1*yx6/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) - c_2*c_6*yx1*yx14/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) - c_2*y_0*yx7/(c_6 + y_0) + 2*c_4*yx12 + c_4*yx5 - yx1*(c_2*y_0*y_2 - (c_0 - c_1*y_0)*(c_6 + y_0))/(c_6 + y_0) - yx11*(3*c_2*y_2*(c_6 + y_0) - c_2*y_2*(2*c_6 + 3*y_0) + (c_1 + 2*c_5)*(c_6 + y_0)**2)/(c_6 + y_0)**2 + yx4*(c_2*c_6*yx1 + 2*c_4*c_6**2*y_1 + 4*c_4*c_6*y_0*y_1 + 2*c_4*y_0**2*y_1 - 2*c_5*c_6**2*y_2 + c_5*c_6**2 - 4*c_5*c_6*y_0*y_2 + 2*c_5*c_6*y_0 - 2*c_5*y_0**2*y_2 + c_5*y_0**2)/(c_6**2 + 2*c_6*y_0 + y_0**2) + (-c_0*c_6*yx1 - c_0*y_0*yx1 + c_1*c_6*y_0*yx1 + c_1*y_0**2*yx1 + c_2*y_0*y_2*yx1 - 2*c_4*c_6*y_1*yx4 - 2*c_4*y_0*y_1*yx4 + 2*c_5*c_6*y_2*yx4 + 2*c_5*y_0*y_2*yx4)/(c_6 + y_0)',
'c_2*c_6*y_2*yx16*yx2/(c_6**4 + 4*c_6**3*y_0 + 6*c_6**2*y_0**2 + 4*c_6*y_0**3 + y_0**4) - c_2*c_6*y_2*yx2*yx6/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) - c_2*y_0*yx8/(c_6 + y_0) + c_4*yx13 - yx12*(2*c_2*y_2*(c_6 + y_0) - c_2*y_2*(c_6 + 2*y_0) + (c_6 + y_0)**2*(c_1 + c_4 + c_5))/(c_6 + y_0)**2 + yx14*(-c_2*c_6*yx2 + c_3*c_6**3 + 3*c_3*c_6**2*y_0 + 3*c_3*c_6*y_0**2 + c_3*y_0**3)/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) - yx2*(-c_0*c_6 - c_0*y_0 + c_1*c_6*y_0 + c_1*y_0**2 + c_2*y_0*y_2)/(c_6 + y_0) + yx4*(c_2*c_6*yx2 + c_3*c_6**2*y_0 + 2*c_3*c_6*y_0**2 + c_3*y_0**3 - c_4*c_6**2*y_1 - 2*c_4*c_6*y_0*y_1 - c_4*y_0**2*y_1)/(c_6**2 + 2*c_6*y_0 + y_0**2) - yx5*(-c_4*y_1 + c_4 + c_5*y_2) + (-c_0*c_6*yx2 - c_0*y_0*yx2 + c_1*c_6*y_0*yx2 + c_1*y_0**2*yx2 + c_2*y_0*y_2*yx2 - c_3*c_6*y_0*yx4 - c_3*y_0**2*yx4 + c_4*c_6*y_1*yx4 - c_4*c_6*y_1*yx5 + c_4*y_0*y_1*yx4 - c_4*y_0*y_1*yx5 + c_5*c_6*y_2*yx5 + c_5*y_0*y_2*yx5)/(c_6 + y_0)',
'c_2*c_6*y_2*yx16*yx3/(c_6**4 + 4*c_6**3*y_0 + 6*c_6**2*y_0**2 + 4*c_6*y_0**3 + y_0**4) - c_2*c_6*yx14*yx3/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) + c_2*c_6*yx3*yx4/(c_6**2 + 2*c_6*y_0 + y_0**2) - c_2*y_0*yx9/(c_6 + y_0) + 2*c_3*yx15 - yx13*(-c_2*y_0*y_2 + c_2*y_2*(c_6 + y_0) + (c_1 + 2*c_4)*(c_6 + y_0)**2)/(c_6 + y_0)**2 - yx3*(c_2*y_0*y_2 - (c_0 - c_1*y_0)*(c_6 + y_0))/(c_6 + y_0) + yx5*(2*c_3*y_0 - 2*c_4*y_1 + c_4) + yx6*(-c_2*c_6*y_2*yx3 + c_3*c_6**3 + 3*c_3*c_6**2*y_0 + 3*c_3*c_6*y_0**2 + c_3*y_0**3)/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) + (-c_0*c_6*yx3 - c_0*y_0*yx3 + c_1*c_6*y_0*yx3 + c_1*y_0**2*yx3 + c_2*y_0*y_2*yx3 - 2*c_3*c_6*y_0*yx5 - 2*c_3*y_0**2*yx5 + 2*c_4*c_6*y_1*yx5 + 2*c_4*y_0*y_1*yx5)/(c_6 + y_0)',
'2*c_2*c_6*y_2*yx16*yx4/(c_6**4 + 4*c_6**3*y_0 + 6*c_6**2*y_0**2 + 4*c_6*y_0**3 + y_0**4) + c_2*y_0*yx1/(c_6 + y_0) - c_2*yx11*(2*c_6*y_0 - c_6 + 2*y_0**2)/(c_6**2 + 2*c_6*y_0 + y_0**2) + c_4*yx15 - yx14*(2*c_1*c_6**3 + 6*c_1*c_6**2*y_0 + 6*c_1*c_6*y_0**2 + 2*c_1*y_0**3 + 2*c_2*c_6**2*y_2 + 2*c_2*c_6*y_0*y_2 + c_2*c_6*y_2 + 2*c_2*c_6*yx4 + c_5*c_6**3 + 3*c_5*c_6**2*y_0 + 3*c_5*c_6*y_0**2 + c_5*y_0**3)/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) + yx4*(2*c_0*c_6**2 + 4*c_0*c_6*y_0 + 2*c_0*y_0**2 - 2*c_1*c_6**2*y_0 + c_1*c_6**2 - 4*c_1*c_6*y_0**2 + 2*c_1*c_6*y_0 - 2*c_1*y_0**3 + c_1*y_0**2 - 2*c_2*c_6*y_0*y_2 + c_2*c_6*y_2 + 2*c_2*c_6*yx4 - 2*c_2*y_0**2*y_2)/(c_6**2 + 2*c_6*y_0 + y_0**2) - yx6*(2*c_2*c_6*y_2*yx4 - c_4*c_6**3*y_1 - 3*c_4*c_6**2*y_0*y_1 - 3*c_4*c_6*y_0**2*y_1 - c_4*y_0**3*y_1 + c_5*c_6**3*y_2 + 3*c_5*c_6**2*y_0*y_2 + 3*c_5*c_6*y_0**2*y_2 + c_5*y_0**3*y_2)/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) + (-2*c_0*c_6*yx4 - 2*c_0*y_0*yx4 + 2*c_1*c_6*y_0*yx4 + 2*c_1*y_0**2*yx4 + 2*c_2*y_0*y_2*yx4 - c_4*c_6*y_1*yx6 - c_4*y_0*y_1*yx6 + c_5*c_6*y_2*yx6 + c_5*y_0*y_2*yx6)/(c_6 + y_0)',
'-2*c_2*c_6*yx14*yx5/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) + 2*c_2*c_6*yx4*yx5/(c_6**2 + 2*c_6*y_0 + y_0**2) + c_2*y_0*yx2/(c_6 + y_0) - c_2*yx12*(2*c_6*y_0 - c_6 + 2*y_0**2)/(c_6**2 + 2*c_6*y_0 + y_0**2) - yx15*(c_2*y_0*y_2*(2*c_6 + 2*y_0 - 1) + 2*c_2*y_2*(c_6 + y_0)**2 - c_2*y_2*(c_6 + y_0)*(4*y_0 - 1) + (2*c_1 + c_4)*(c_6 + y_0)**3)/(c_6 + y_0)**3 + yx16*(2*c_2*c_6*y_2*yx5 + c_3*c_6**4 + 4*c_3*c_6**3*y_0 + 6*c_3*c_6**2*y_0**2 + 4*c_3*c_6*y_0**3 + c_3*y_0**4)/(c_6**4 + 4*c_6**3*y_0 + 6*c_6**2*y_0**2 + 4*c_6*y_0**3 + y_0**4) + yx5*(2*c_0 - 4*c_1*y_0 + c_1 + 2*c_2*y_0**2*y_2/(c_6 + y_0)**2 - 4*c_2*y_0*y_2/(c_6 + y_0) - c_2*y_0*y_2/(c_6 + y_0)**2 + c_2*y_2/(c_6 + y_0) - 2*c_4*y_0 + 2*y_0*(c_1 - c_2*y_0*y_2/(c_6 + y_0)**2 + c_2*y_2/(c_6 + y_0) + c_4)) - yx6*(2*c_2*c_6*y_2*yx5 - c_3*c_6**3*y_0 - 3*c_3*c_6**2*y_0**2 - 3*c_3*c_6*y_0**3 - c_3*y_0**4 + c_4*c_6**3*y_1 + 3*c_4*c_6**2*y_0*y_1 + 3*c_4*c_6*y_0**2*y_1 + c_4*y_0**3*y_1)/(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3) + (-2*c_0*c_6*yx5 - 2*c_0*y_0*yx5 + 2*c_1*c_6*y_0*yx5 + 2*c_1*y_0**2*yx5 + 2*c_2*y_0*y_2*yx5 - c_3*c_6*y_0*yx6 - c_3*y_0**2*yx6 + c_4*c_6*y_1*yx6 + c_4*y_0*y_1*yx6)/(c_6 + y_0)',
'-(-c_2*yx4*(c_6 + y_0)*(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3)*(3*c_6*y_0 + 3*c_6*yx6 - c_6 + 3*y_0**2)*(c_6**4 + 4*c_6**3*y_0 + 6*c_6**2*y_0**2 + 4*c_6*y_0**3 + y_0**4) + yx16*(c_6 + y_0)*(c_6**2 + 2*c_6*y_0 + y_0**2)*(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3)*(3*c_1*c_6**4 + 12*c_1*c_6**3*y_0 + 18*c_1*c_6**2*y_0**2 + 12*c_1*c_6*y_0**3 + 3*c_1*y_0**4 + 3*c_2*c_6**3*y_2 + 6*c_2*c_6**2*y_0*y_2 + 3*c_2*c_6**2*y_2 + 3*c_2*c_6*y_0**2*y_2 + 3*c_2*c_6*y_0*y_2 - 3*c_2*c_6*y_2*yx6 + c_2*c_6*y_2) - (c_6 + y_0)*(-c_2*yx14*(3*c_6**2*y_0 - 3*c_6**2 + 6*c_6*y_0**2 - 3*c_6*y_0 + 3*c_6*yx6 - c_6 + 3*y_0**3) + yx6*(3*c_0*c_6**3 + 9*c_0*c_6**2*y_0 + 9*c_0*c_6*y_0**2 + 3*c_0*y_0**3 - 3*c_1*c_6**3*y_0 + 3*c_1*c_6**3 - 9*c_1*c_6**2*y_0**2 + 9*c_1*c_6**2*y_0 - 9*c_1*c_6*y_0**3 + 9*c_1*c_6*y_0**2 - 3*c_1*y_0**4 + 3*c_1*y_0**3 - 3*c_2*c_6**2*y_0*y_2 + 3*c_2*c_6**2*y_2 - 6*c_2*c_6*y_0**2*y_2 + 3*c_2*c_6*y_0*y_2 - 3*c_2*c_6*y_2*yx6 + c_2*c_6*y_2 - 3*c_2*y_0**3*y_2))*(c_6**2 + 2*c_6*y_0 + y_0**2)*(c_6**4 + 4*c_6**3*y_0 + 6*c_6**2*y_0**2 + 4*c_6*y_0**3 + y_0**4) - (c_6**2 + 2*c_6*y_0 + y_0**2)*(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3)*(c_6**4 + 4*c_6**3*y_0 + 6*c_6**2*y_0**2 + 4*c_6*y_0**3 + y_0**4)*(-3*c_0*c_6*yx6 + c_0*c_6 - 3*c_0*y_0*yx6 + c_0*y_0 + 3*c_1*c_6*y_0*yx6 - c_1*c_6*y_0 + 3*c_1*y_0**2*yx6 - c_1*y_0**2 + 3*c_2*y_0*y_2*yx6 - c_2*y_0*y_2))/((c_6 + y_0)*(c_6**2 + 2*c_6*y_0 + y_0**2)*(c_6**3 + 3*c_6**2*y_0 + 3*c_6*y_0**2 + y_0**3)*(c_6**4 + 4*c_6**3*y_0 + 6*c_6**2*y_0**2 + 4*c_6*y_0**3 + y_0**4))'])

# %%
initial_constants = np.array([90, 0.002, 1.2, 1.1, 0.8, 0.96, 0.01]) # initial values for `constants` -- not modified during ODE solving

# %%
initial_moments= np.array([80, 40, 60] + [0] * 16) # initial values for `variables`

# %%
# Check that rhs equations can be evaluated in terms of constants and variables
rhs_equations.evalf(subs=dict(zip(constants, initial_constants) + zip(variables, initial_moments)))
# Out:
# [17.8489988751406]
# [            56.0]
# [           -25.6]
# [            89.6]
# [           -32.0]
# [           120.0]
# [               0]
# [               0]
# [162.151001124859]
# [           -25.6]
# [           -32.0]
# [            32.0]
# [            56.0]
# [               0]
# [               0]
# [               0]
# [               0]
# [               0]
# [17.8489988751406]

# %%
def rhs(t, y):
    expression_substitution_dictionary = dict(zip(constants, initial_constants) + zip(variables, y)) # This dictionary creation may become a bottleneck and may need to be dealt with
    return rhs_equations.evalf(subs=expression_substitution_dictionary)

# %%
# Test our rhs function
rhs(0, initial_moments)
# Out:
# [17.8489988751406]
# [            56.0]
# [           -25.6]
# [            89.6]
# [           -32.0]
# [           120.0]
# [               0]
# [               0]
# [162.151001124859]
# [           -25.6]
# [           -32.0]
# [            32.0]
# [            56.0]
# [               0]
# [               0]
# [               0]
# [               0]
# [               0]
# [17.8489988751406]

# %%
from assimulo.problem import Explicit_Problem
from assimulo.solvers.sundials import CVode

# %%
model = Explicit_Problem(rhs, initial_moments, start_time) # Wrapping our knowledge about the model into single place

# %%
solver = CVode(model) # This is essentially the "compilation" step in previous year's project

# %%
# Run the simulation the returned lists are lists of timepoints, and values of y vector at each of them
# ncp specifies how many timepoints to evaluate, this can roughly be approximated from end, start times and the timestep
t, y = solver.simulate(end_time, ncp=int((end_time-start_time)/timestep)) # note that solver instance stores state of last simulation and continues forward from it
# Out:
# Final Run Statistics: ---
#
#  Number of Steps                          : 294
#  Number of Function Evaluations           : 323
#  Number of Jacobian Evaluations           : 6
#  Number of F-Eval During Jac-Eval         : 114
#  Number of Root Evaluations               : 0
#  Number of Error Test Failures            : 0
#  Number of Newton Iterations              : 319
#  Number of Newton Convergence Failures    : 0
#
# Solver options:
#
#  Solver                  : CVode
#  Linear Multistep Method : BDF
#  Nonlinear Solver        : Newton
#  Maxord                  : 5
#  Tolerances (absolute)   : [  1.00000000e-06   1.00000000e-06   1.00000000e-06   1.00000000e-06
#    1.00000000e-06   1.00000000e-06   1.00000000e-06   1.00000000e-06
#    1.00000000e-06   1.00000000e-06   1.00000000e-06   1.00000000e-06
#    1.00000000e-06   1.00000000e-06   1.00000000e-06   1.00000000e-06
#    1.00000000e-06   1.00000000e-06   1.00000000e-06]
#  Tolerances (relative)   : 1e-06
#
# ...

# %%
import pylab

# %%
len(variables)
# Out:
# 19

# %%
# Reproducing plot from previous year's project
# Original available here: http://i.imgur.com/rmWk9XM.png
pylab.rcParams['figure.figsize'] = (16.0, 14.0) # increase plot figure size so we can actually fit things in

# Note that the original image fits only 9 moments to it's 3x3 grid. I therefore use a 4x5 grid to fit all of them
plot_rows = 4
plot_columns = 5
pylab.subplot(plot_rows, plot_columns, 1)
pylab.plot(t, y[:,0], label=variables[0])
pylab.plot(t, y[:,1], label=variables[1])
pylab.plot(t, y[:,2], label=variables[1])
pylab.title('Means')
pylab.legend()

for subplot_index, data_index in zip(range(2, 18), range(3, 19)):
    pylab.subplot(plot_rows, plot_columns, subplot_index)
    pylab.plot(t, y[:,data_index], label=variables[data_index])
    pylab.title(variables[data_index])
